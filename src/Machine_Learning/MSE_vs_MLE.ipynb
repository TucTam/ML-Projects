# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../../datasets/Salary_dataset.csv")
scaler = StandardScaler()
data.iloc[:,1] = scaler.fit_transform(np.asarray(data.iloc[:,1]).reshape(-1,1))
data.iloc[:,2] = scaler.fit_transform(np.asarray(data.iloc[:,2]).reshape(-1,1))
data
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0        -1.510053 -1.360113
# 1            1        -1.438373 -1.105527
# 2            2        -1.366693 -1.419919
# 3            3        -1.187494 -1.204957
# 4            4        -1.115814 -1.339781
# 5            5        -0.864935 -0.718307
# 6            6        -0.829096 -0.588158
# 7            7        -0.757416 -0.799817
# 8            8        -0.757416 -0.428810
# 9            9        -0.578216 -0.698013
# 10          10        -0.506537 -0.474333
# 11          11        -0.470697 -0.749769
# 12          12        -0.470697 -0.706620
# 13          13        -0.434857 -0.702020
# 14          14        -0.291498 -0.552504
# 15          15        -0.148138 -0.299217
# 16          16        -0.076458 -0.370043
# 17          17        -0.004779  0.262859
# 18          18         0.210261  0.198860
# 19          19         0.246100  0.665476
# 20          20         0.532819  0.583780
# ...

# %%
plt.xlabel("Years Of Experience")
plt.ylabel("Salary")
plt.scatter(data.iloc[:, 1], data.iloc[:, 2])

# %%
xtrain, xtest, ytrain, ytest = train_test_split(data.iloc[:,1], data.iloc[:,2])

# %%
model_MSE = LinearRegression()
model_MLE =

# %%
model_MSE.fit(np.asarray(xtrain).reshape(-1,1), np.asarray(ytrain).reshape(-1,1))
# Out:
# LinearRegression()

# %%
preds = model_MSE.predict(np.asarray(xtest).reshape(-1,1))

# %%
plt.scatter(xtest, ytest)
plt.plot(xtest, preds)
plt.scatter(xtrain, ytrain)
